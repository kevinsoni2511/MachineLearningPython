# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=sns.load_dataset('car_crashes')
data
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
a=data[['speeding','total']]
a
# Out:
#     speeding  total
# 0      7.332   18.8
# 1      7.421   18.1
# 2      6.510   18.6
# 3      4.032   22.4
# 4      4.200   12.0
# 5      5.032   13.6
# 6      4.968   10.8
# 7      6.156   16.2
# 8      2.006    5.9
# 9      3.759   17.9
# 10     2.964   15.6
# 11     9.450   17.5
# 12     5.508   15.3
# 13     4.608   12.8
# 14     3.625   14.5
# 15     2.669   15.7
# 16     4.806   17.8
# 17     4.066   21.4
# 18     7.175   20.5
# 19     5.738   15.1
# 20     4.250   12.5
# 21     1.886    8.2
# 22     3.384   14.1
# 23     2.208    9.6
# 24     2.640   17.6
# 25     6.923   16.1
# 26     8.346   21.4
# 27     1.937   14.9
# 28     5.439   14.7
# 29     4.060   11.6
# 30     1.792   11.2
# 31     3.496   18.4
# 32     3.936   12.3
# 33     6.552   16.8
# 34     5.497   23.9
# 35     3.948   14.1
# 36     6.368   19.9
# 37     4.224   12.8
# 38     9.100   18.2
# 39     3.774   11.1
# 40     9.082   23.9
# 41     6.014   19.4
# 42     4.095   19.5
# 43     7.760   19.4
# ...

# %%
a=data.head(5)
a
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
a=data.tail(5)
a
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
a=data.describe()
a
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
a=data['total'].count(),data['total'].min()
a
# Out:
# (51, 5.9)

# %%
a=data[['total','speeding']].count()# with multiple field
a
# Out:
# total       51
# speeding    51
# dtype: int64

# %%
data['fine']=data['total']*data['speeding']
data['fine']
# Out:
# 0     137.8416
# 1     134.3201
# 2     121.0860
# 3      90.3168
# 4      50.4000
# 5      68.4352
# 6      53.6544
# 7      99.7272
# 8      11.8354
# 9      67.2861
# 10     46.2384
# 11    165.3750
# 12     84.2724
# 13     58.9824
# 14     52.5625
# 15     41.9033
# 16     85.5468
# 17     87.0124
# 18    147.0875
# 19     86.6438
# 20     53.1250
# 21     15.4652
# 22     47.7144
# 23     21.1968
# 24     46.4640
# 25    111.4603
# 26    178.6044
# 27     28.8613
# 28     79.9533
# 29     47.0960
# 30     20.0704
# 31     64.3264
# 32     48.4128
# 33    110.0736
# 34    131.3783
# 35     55.6668
# 36    126.7232
# 37     54.0672
# 38    165.6200
# 39     41.8914
# 40    217.0598
# 41    116.6716
# 42     79.8525
# 43    150.5440
# 44     54.9067
# 45     55.4880
# 46     30.6451
# 47     47.1912
# 48    192.5896
# 49     68.5584
# 50    127.1592
# Name: fine, dtype: float64

# %%
data# by default tabular format
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
h=np.hstack(data['total'])# record display  in horizantally
h
# Out:
# array([18.8, 18.1, 18.6, 22.4, 12. , 13.6, 10.8, 16.2,  5.9, 17.9, 15.6,
#        17.5, 15.3, 12.8, 14.5, 15.7, 17.8, 21.4, 20.5, 15.1, 12.5,  8.2,
#        14.1,  9.6, 17.6, 16.1, 21.4, 14.9, 14.7, 11.6, 11.2, 18.4, 12.3,
#        16.8, 23.9, 14.1, 19.9, 12.8, 18.2, 11.1, 23.9, 19.4, 19.5, 19.4,
#        11.3, 13.6, 12.7, 10.6, 23.8, 13.8, 17.4])

# %%
v=np.vstack(data['speeding'])# vertically
v
# Out:
# array([[7.332],
#        [7.421],
#        [6.51 ],
#        [4.032],
#        [4.2  ],
#        [5.032],
#        [4.968],
#        [6.156],
#        [2.006],
#        [3.759],
#        [2.964],
#        [9.45 ],
#        [5.508],
#        [4.608],
#        [3.625],
#        [2.669],
#        [4.806],
#        [4.066],
#        [7.175],
#        [5.738],
#        [4.25 ],
#        [1.886],
#        [3.384],
#        [2.208],
#        [2.64 ],
#        [6.923],
#        [8.346],
#        [1.937],
#        [5.439],
#        [4.06 ],
#        [1.792],
#        [3.496],
#        [3.936],
#        [6.552],
#        [5.497],
#        [3.948],
#        [6.368],
#        [4.224],
#        [9.1  ],
#        [3.774],
#        [9.082],
#        [6.014],
#        [4.095],
#        [7.76 ],
#        [4.859],
#        [4.08 ],
#        [2.413],
#        [4.452],
#        [8.092],
#        [4.968],
#        [7.308]])

# %%
abc=data.groupby('total')['speeding'].min()# group by using min
abc
# Out:
# total
# 5.9     2.006
# 8.2     1.886
# 9.6     2.208
# 10.6    4.452
# 10.8    4.968
# 11.1    3.774
# 11.2    1.792
# 11.3    4.859
# 11.6    4.060
# 12.0    4.200
# 12.3    3.936
# 12.5    4.250
# 12.7    2.413
# 12.8    4.224
# 13.6    4.080
# 13.8    4.968
# 14.1    3.384
# 14.5    3.625
# 14.7    5.439
# 14.9    1.937
# 15.1    5.738
# 15.3    5.508
# 15.6    2.964
# 15.7    2.669
# 16.1    6.923
# 16.2    6.156
# 16.8    6.552
# 17.4    7.308
# 17.5    9.450
# 17.6    2.640
# 17.8    4.806
# 17.9    3.759
# 18.1    7.421
# 18.2    9.100
# 18.4    3.496
# 18.6    6.510
# 18.8    7.332
# 19.4    6.014
# 19.5    4.095
# 19.9    6.368
# 20.5    7.175
# 21.4    4.066
# 22.4    4.032
# 23.8    8.092
# 23.9    5.497
# Name: speeding, dtype: float64

# %%
abc=data.groupby('total')['speeding'].std()# group by using min
abc
# Out:
# total
# 5.9          NaN
# 8.2          NaN
# 9.6          NaN
# 10.6         NaN
# 10.8         NaN
# 11.1         NaN
# 11.2         NaN
# 11.3         NaN
# 11.6         NaN
# 12.0         NaN
# 12.3         NaN
# 12.5         NaN
# 12.7         NaN
# 12.8    0.271529
# 13.6    0.673166
# 13.8         NaN
# 14.1    0.398808
# 14.5         NaN
# 14.7         NaN
# 14.9         NaN
# 15.1         NaN
# 15.3         NaN
# 15.6         NaN
# 15.7         NaN
# 16.1         NaN
# 16.2         NaN
# 16.8         NaN
# 17.4         NaN
# 17.5         NaN
# 17.6         NaN
# 17.8         NaN
# 17.9         NaN
# 18.1         NaN
# 18.2         NaN
# 18.4         NaN
# 18.6         NaN
# 18.8         NaN
# 19.4    1.234608
# 19.5         NaN
# 19.9         NaN
# 20.5         NaN
# 21.4    3.026417
# 22.4         NaN
# 23.8         NaN
# 23.9    2.534978
# Name: speeding, dtype: float64

# %%
training=data.iloc[8:13]# vache na print karva hoi tyre iloc use karvu pdeeeee...
training
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# 12   15.3     5.508    4.437          13.005       14.994       641.96
#
#     ins_losses abbrev      fine
# 8       136.05     DC   11.8354
# 9       144.18     FL   67.2861
# 10      142.80     GA   46.2384
# 11      120.92     HI  165.3750
# 12       82.75     ID   84.2724

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression

# %%
X = data.drop(columns=['speeding'])  # Features independent variable
y = data['speeding']  # Target variable depe
X,y
# Out:
# (    total  alcohol  not_distracted  no_previous  ins_premium  ins_losses  \
#  0    18.8    5.640          18.048       15.040       784.55      145.08
#  1    18.1    4.525          16.290       17.014      1053.48      133.93
#  2    18.6    5.208          15.624       17.856       899.47      110.35
#  3    22.4    5.824          21.056       21.280       827.34      142.39
#  4    12.0    3.360          10.920       10.680       878.41      165.63
#  5    13.6    3.808          10.744       12.920       835.50      139.91
#  6    10.8    3.888           9.396        8.856      1068.73      167.02
#  7    16.2    4.860          14.094       16.038      1137.87      151.48
#  8     5.9    1.593           5.900        5.900      1273.89      136.05
#  9    17.9    5.191          16.468       16.826      1160.13      144.18
#  10   15.6    3.900          14.820       14.508       913.15      142.80
#  11   17.5    7.175          14.350       15.225       861.18      120.92
# ...

# %%
data
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train, X_test, y_train, y_test
# Out:
# (    total  alcohol  not_distracted  no_previous  ins_premium  ins_losses  \
#  19   15.1    4.530          13.137       12.684       661.88       96.57
#  2    18.6    5.208          15.624       17.856       899.47      110.35
#  45   13.6    4.080          13.056       12.920       716.20      109.61
#  34   23.9   10.038          23.661       20.554       688.75      109.72
#  32   12.3    3.567          10.824        9.840      1234.31      150.01
#  12   15.3    4.437          13.005       14.994       641.96       82.75
#  42   19.5    5.655          15.990       15.795       767.91      155.57
#  48   23.8    6.664          23.086       20.706       992.61      152.56
#  20   12.5    4.000           8.875       12.375      1048.78      192.70
#  50   17.4    5.568          14.094       15.660       791.14      122.04
#  40   23.9    9.799          22.944       19.359       858.97      116.29
#  39   11.1    4.218          10.212        8.769      1148.99      148.58
# ...

# %%
a=len(data) # length of data
a
# Out:
# 51

# %%
plt.plot(data['total'],data['speeding'],marker='*',color='b',ms=10,mfc='w')# ms means marker size , mec means marker egde color

# %%
plt.title('Line Chart')#title
plt.xlabel('tata')
plt.ylabel('byy')
plt.plot(data[['speeding','alcohol']])

# %%
plt.title('Bar Graph')
plt.xlabel('tata')
plt.ylabel('adani')
plt.barh(data['total'],data['speeding'],color='#4e6d69')# barh means bar horizantal, not used for v for vartically
# Out:
# <BarContainer object of 51 artists>

# %%
plt.hist(data[['total','speeding']])# hist means histogram
plt.title('histogram')
# Out:
# Text(0.5, 1.0, 'histogram')

# %%
b=['total','speeding','tata']
a=[1,2,3]
plt.pie(a,labels=b)
plt.legend()

# %%
a=['total','speed']
b=[1,2]
plt.pie(b,labels=a)
plt.legend()

# %%
data=['total','speeding','alcohol']
a=[1,2,3]
plt.pie(a,labels=data)
plt.legend()

# %%
data=sns.load_dataset('iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data=sns.load_dataset('car_crashes')
data
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
plt.pie(data['speeding'],labels=data['alcohol'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7b54e53ba690>,
# ...
#  [Text(1.0955120823685824, 0.09926367605751948, '5.64'),
#   Text(1.0595044353965717, 0.295720055753735, '4.525'),
#   Text(0.9934032096081563, 0.4723876195882083, '5.208000000000001'),
#   Text(0.9238285752701308, 0.597110344504565, '5.824'),
#   Text(0.8586024253215532, 0.6876059011032023, '3.36'),
#   Text(0.7749843890730241, 0.7806402479331384, '3.808'),
#   Text(0.6731401678570539, 0.8699898358126821, '3.888'),
#   Text(0.5479244871986134, 0.9538232311744859, '4.86'),
#   Text(0.44936950791516883, 1.0040254206722452, '1.5930000000000002'),
#   Text(0.3769594706676002, 1.0333932249990818, '5.190999999999999'),
#   Text(0.2901402518597424, 1.061046009488168, '3.9'),
#   Text(0.12504861921560517, 1.0928690876917833, '7.175'),
#   Text(-0.07739996070202175, 1.0972735511636675, '4.437'),
#   Text(-0.21324635828140381, 1.0791320543287182, '4.352'),
#   Text(-0.32145798924460206, 1.051981350191541, '4.205'),
# ...

# %%
dataa=data.groupby('total')['speeding'].sum()
dataa
# Out:
# total
# 5.9      2.006
# 8.2      1.886
# 9.6      2.208
# 10.6     4.452
# 10.8     4.968
# 11.1     3.774
# 11.2     1.792
# 11.3     4.859
# 11.6     4.060
# 12.0     4.200
# 12.3     3.936
# 12.5     4.250
# 12.7     2.413
# 12.8     8.832
# 13.6     9.112
# 13.8     4.968
# 14.1     7.332
# 14.5     3.625
# 14.7     5.439
# 14.9     1.937
# 15.1     5.738
# 15.3     5.508
# 15.6     2.964
# 15.7     2.669
# 16.1     6.923
# 16.2     6.156
# 16.8     6.552
# 17.4     7.308
# 17.5     9.450
# 17.6     2.640
# 17.8     4.806
# 17.9     3.759
# 18.1     7.421
# 18.2     9.100
# 18.4     3.496
# 18.6     6.510
# 18.8     7.332
# 19.4    13.774
# 19.5     4.095
# 19.9     6.368
# 20.5     7.175
# 21.4    12.412
# 22.4     4.032
# 23.8     8.092
# 23.9    14.579
# Name: speeding, dtype: float64

# %%
data1=sns.load_dataset('iris')
data1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
dataa=data1.groupby('species')['sepal_length'].sum()
dataa
# Out:
# species
# setosa        250.3
# versicolor    296.8
# virginica     329.4
# Name: sepal_length, dtype: float64

# %%
dataaaa=data1['species'].unique()
dataaaa
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
cc=data1['species'].value_counts()
cc
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
x=sns.get_dataset_names()
x
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
c=sns.load_dataset('anscombe')
c
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from sklearn import linear_model

# %%
plt.scatter(data1['sepal_length'],data1['sepal_width'])

# %%
# Convert species numbers to names
df['species'] = df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

# Scatter plot
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['sepal_length'], y=df['sepal_width'], hue=df['species'])
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.title("Sepal Length vs Sepal Width by Species")
plt.show()

# %%
df.sort_values(['petal_length'],ascending=0)# 0 for decending & 1 for ascending
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 118           7.7          2.6           6.9          2.3     NaN
# 122           7.7          2.8           6.7          2.0     NaN
# 117           7.7          3.8           6.7          2.2     NaN
# 105           7.6          3.0           6.6          2.1     NaN
# 131           7.9          3.8           6.4          2.0     NaN
# ..            ...          ...           ...          ...     ...
# 16            5.4          3.9           1.3          0.4     NaN
# 35            5.0          3.2           1.2          0.2     NaN
# 14            5.8          4.0           1.2          0.2     NaN
# 13            4.3          3.0           1.1          0.1     NaN
# 22            4.6          3.6           1.0          0.2     NaN
#
# [150 rows x 5 columns]

# %%
a=df['sepal_length']<1 # filtering data with <1 if value is <1 print flase & >1 print true
a
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: sepal_length, Length: 150, dtype: bool
