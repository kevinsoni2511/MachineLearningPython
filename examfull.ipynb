# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dd=sns.load_dataset('iris') # to load iris data set
dd
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
kn=sns.get_dataset_names() # to get all inbuild data set name
print(kn)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
ll=sns.load_dataset('car_crashes')
ll
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
aa=sns.load_dataset('diamonds')
aa
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# **TO DISPLAY SPECIFIC FIELD FROM DATABASE**

# %%
a=dd[['sepal_length','sepal_width']] # to display specific fields from table
a
print(dd['petal_width'])
aa=dd[['sepal_length','petal_width','species']]
aa
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal_width, Length: 150, dtype: float64
#      sepal_length  petal_width    species
# 0             5.1          0.2     setosa
# 1             4.9          0.2     setosa
# 2             4.7          0.2     setosa
# 3             4.6          0.2     setosa
# 4             5.0          0.2     setosa
# ..            ...          ...        ...
# 145           6.7          2.3  virginica
# 146           6.3          1.9  virginica
# 147           6.5          2.0  virginica
# 148           6.2          2.3  virginica
# 149           5.9          1.8  virginica
#
# [150 rows x 3 columns]

# %% [markdown]
# Want first 20 Reciords

# %%
print(aa.head(20))
# Out:
#     sepal_length  petal_width species
# 0            5.1          0.2  setosa
# 1            4.9          0.2  setosa
# 2            4.7          0.2  setosa
# 3            4.6          0.2  setosa
# 4            5.0          0.2  setosa
# 5            5.4          0.4  setosa
# 6            4.6          0.3  setosa
# 7            5.0          0.2  setosa
# 8            4.4          0.2  setosa
# 9            4.9          0.1  setosa
# 10           5.4          0.2  setosa
# 11           4.8          0.2  setosa
# 12           4.8          0.1  setosa
# 13           4.3          0.1  setosa
# 14           5.8          0.2  setosa
# 15           5.7          0.4  setosa
# 16           5.4          0.4  setosa
# 17           5.1          0.3  setosa
# 18           5.7          0.3  setosa
# 19           5.1          0.3  setosa

# %%
# Out:
#      sepal_length  petal_width    species
# 130           7.4          1.9  virginica
# 131           7.9          2.0  virginica
# 132           6.4          2.2  virginica
# 133           6.3          1.5  virginica
# 134           6.1          1.4  virginica
# 135           7.7          2.3  virginica
# 136           6.3          2.4  virginica
# 137           6.4          1.8  virginica
# 138           6.0          1.8  virginica
# 139           6.9          2.1  virginica
# 140           6.7          2.4  virginica
# 141           6.9          2.3  virginica
# 142           5.8          1.9  virginica
# 143           6.8          2.3  virginica
# 144           6.7          2.5  virginica
# 145           6.7          2.3  virginica
# 146           6.3          1.9  virginica
# 147           6.5          2.0  virginica
# 148           6.2          2.3  virginica
# 149           5.9          1.8  virginica

# %% [markdown]
# Want last 20 records

# %%
print(aa.tail(20))
# Out:
#      sepal_length  petal_width    species
# 130           7.4          1.9  virginica
# 131           7.9          2.0  virginica
# 132           6.4          2.2  virginica
# 133           6.3          1.5  virginica
# 134           6.1          1.4  virginica
# 135           7.7          2.3  virginica
# 136           6.3          2.4  virginica
# 137           6.4          1.8  virginica
# 138           6.0          1.8  virginica
# 139           6.9          2.1  virginica
# 140           6.7          2.4  virginica
# 141           6.9          2.3  virginica
# 142           5.8          1.9  virginica
# 143           6.8          2.3  virginica
# 144           6.7          2.5  virginica
# 145           6.7          2.3  virginica
# 146           6.3          1.9  virginica
# 147           6.5          2.0  virginica
# 148           6.2          2.3  virginica
# 149           5.9          1.8  virginica

# %% [markdown]
#  **mean, median, standard
# deviation, minimum, and maximum values**

# %%
ALL=dd.describe()
print(ALL)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dd=sns.load_dataset('iris')
dd
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
AA=dd[['sepal_length','sepal_width','petal_length','petal_width']]
AA
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# Dhyan rakhna ki bhul se bhi space nhi chod nhi

# %%
print(AA.mean())
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
print(AA.median())
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
print(AA.std())
# Out:
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64

# %% [markdown]
# **For standard deviattion we use std**

# %%
print(AA.min())
# Out:
# sepal_length    4.3
# sepal_width     2.0
# petal_length    1.0
# petal_width     0.1
# dtype: float64

# %%
print(AA.max())
# Out:
# sepal_length    7.9
# sepal_width     4.4
# petal_length    6.9
# petal_width     2.5
# dtype: float64

# %% [markdown]
# Mean,max,min,mode,median,std for Specifc field

# %%
Data=dd['sepal_length'].mean()
Data

#replace mean with what you want

# %% [markdown]
# Sum

# %%
print(dd.sum())
# Out:
# sepal_length                                                876.5
# sepal_width                                                 458.6
# petal_length                                                563.7
# petal_width                                                 179.9
# species         setosasetosasetosasetosasetosasetosasetosaseto...
# dtype: object

# %% [markdown]
# **Format**

# %%
print("size{}".format(dd.size))
print("dtypes{}".format(dd.dtypes))
# Out:
# size750
# dtypessepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# **Vertical and Horizontal print data we use numpy**

# %%
v=np.hstack(dd['sepal_length'])
v
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])

# %% [markdown]
# **Add new field**

# %%
dd['spel_area']=dd['sepal_length']*dd['sepal_width']
dd
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      spel_area
# 0        17.85
# 1        14.70
# 2        15.04
# 3        14.26
# 4        18.00
# ..         ...
# 145      20.10
# ...

# %%
dd11=dd.groupby('species')['sepal_length'].mean()
dd11
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %% [markdown]
# ## **iloc  .** Split the dataset into two parts, one for training and other for testing in 80:20 ratio

# %%
training=dd.iloc[:120]# First 120 rows for training (80%)
testing=dd.iloc[120:]# First 30 rows for training (80%)

print("the training record  is ",training)
print("the testing record  is ",testing)
# Out:
# the training record  is       sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 115           6.4          3.2           5.3          2.3  virginica
# 116           6.5          3.0           5.5          1.8  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 119           6.0          2.2           5.0          1.5  virginica
#
#      spel_area
# 0        17.85
# 1        14.70
# 2        15.04
# 3        14.26
# 4        18.00
# ...

# %%
print(len(dd))
# Out:
# 150

# %% [markdown]
# Matplotib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# USING ARRAY

# %%
a1=np.array([1,8,3,6,9])
a2=np.array([1,5,3,9,10])

plt.plot(a1,a2)

plt.plot(a1,a2,marker="X")

plt.plot(a1,a2,marker="*",ms='10',mec='pink',mfc="yellow")#ms marker size mec marker edge color mfc marker filled color

plt.plot(a1,a2,linestyle='dotted',color='y',linewidth='5')

# %% [markdown]
# **using csv or import irirs**

# %%
plt.plot(dd.sepal_length,dd.sepal_width)
#or
plt.plot(dd['sepal_length'],dd['sepal_width'])

plt.plot(dd.sepal_length,dd.sepal_width,marker="*",mec='b',mfc='w')

# %%
font={'color':'blue','size':'20'}
plt.title("line chart",fontdict=font,loc='Right')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.plot(dd['sepal_length'],dd['sepal_width'])

# %%
plt.bar(dd['sepal_length'],dd['sepal_width'])

plt.bar(dd['sepal_length'],dd['sepal_width'],color='r')

plt.xlabel("aaa")

plt.ylabel("bbb")
f={'color':'black'}

plt.title("bar Graph",fontdict=f,)
# Out:
# Text(0.5, 1.0, 'bar Graph')

# %%
plt.barh(dd['sepal_length'],dd['sepal_width'])
# Out:
# <BarContainer object of 150 artists>

# %%
plt.hist(dd['sepal_width'])

plt.title("Histogram ")
# Out:
# Text(0.5, 1.0, 'Histogram ')

# %%
a=np.array([1,2,3])
b=np.array([3,1,2])
plt.bar(a,b)
# Out:
# <BarContainer object of 3 artists>

# %%
A=np.array([1,2,3,4])
B=['Apple','Mango','pineapple','kiwi']
plt.pie(A,labels=B)
plt.legend()

# %%
plt.pie(dd['sepal_length'],labels=dd['species'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-43e7c6ec9fe8> in <cell line: 0>()
#       1 plt.pie(dd['sepal_length'],labels=dd['species'])
# ----> 2 x
#
# NameError: name 'x' is not defined

# %%
# if i want to have based on speices count

# %%
Ab=sns.load_dataset('iris')
Ab
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ABB=Ab.groupby('species')['petal_length'].sum()
ABB
# Out:
# species
# setosa         73.1
# versicolor    213.0
# virginica     277.6
# Name: petal_length, dtype: float64

# %% [markdown]
# **Unique row **

# %%
Uniq=Ab['species'].unique()
Uniq
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
ex=[.3,0,0]
plt.pie(ABB,labels=Uniq,explode=ex,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x796861671e50>,
# ...
#  [Text(1.285416694063084, 0.5547106656843115, 'setosa'),
#   Text(-0.45964164325367257, 0.9993645780129812, 'versicolor'),
#   Text(0.02605193360656737, -1.099691455252499, 'virginica')])

# %% [markdown]
# Regression

# %%
cc=Ab['species'].value_counts()
cc
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
e=[0,.1,0]
plt.pie(cc,labels=Uniq,explode=e,shadow=True)
plt.legend()

# %%
Ab.sort_values(['petal_width'],ascending=1)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 32            5.2          4.1           1.5          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 37            4.9          3.6           1.4          0.1     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ..            ...          ...           ...          ...        ...
# 140           6.7          3.1           5.6          2.4  virginica
# 114           5.8          2.8           5.1          2.4  virginica
# 100           6.3          3.3           6.0          2.5  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 109           7.2          3.6           6.1          2.5  virginica
#
# [150 rows x 5 columns]

# %%
a=np.array([1,2,3])
b=np.array([3,1,2])
plt.bar(a,b)
# Out:
# <BarContainer object of 3 artists>

# %%
#two in one graphp
plt.bar(dd['sepal_length'],dd['sepal_width'])

a=np.array([1,2,3])
b=np.array([3,1,2])
plt.bar(a,b)

# %% [markdown]
# **Scatter Graph**

# %%
plt.scatter(Ab['sepal_length'],	Ab['sepal_width'])

# %%
sns.scatterplot(x=Ab['sepal_length'], y=Ab['sepal_width'], hue=Ab['species'], palette='viridis')
plt.legend(title='Species')
plt.show()

# %%
dab=sns.load_dataset('iris')
dab
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
