# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=sns.load_dataset('iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#only staring record print
d=data.head(7)# specific
d
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
#only last ten record print
a=data.tail(10)
a
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
#specific record print karavo 8 thi 16
data.iloc[8:17]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 14           5.8          4.0           1.2          0.2  setosa
# 15           5.7          4.4           1.5          0.4  setosa
# 16           5.4          3.9           1.3          0.4  setosa

# %%
#all calculate
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.min()
# Out:
# sepal_length       4.3
# sepal_width        2.0
# petal_length       1.0
# petal_width        0.1
# species         setosa
# dtype: object

# %%
#perticular filed mate std .. std is not working in string it cant convert string into float..
a=data[['sepal_width','sepal_length']].std()
a
# Out:
# sepal_width     0.435866
# sepal_length    0.828066
# dtype: float64

# %%
#specific 2 field print karava
data[['sepal_width','sepal_length']]
# Out:
#      sepal_width  sepal_length
# 0            3.5           5.1
# 1            3.0           4.9
# 2            3.2           4.7
# 3            3.1           4.6
# 4            3.6           5.0
# ..           ...           ...
# 145          3.0           6.7
# 146          2.5           6.3
# 147          3.0           6.5
# 148          3.4           6.2
# 149          3.0           5.9
#
# [150 rows x 2 columns]

# %%
# Add new field
data['total']=data['sepal_length']+data['sepal_width']
data['total']
# Out:
# 0      8.6
# 1      7.9
# 2      7.9
# 3      7.7
# 4      8.6
#       ...
# 145    9.7
# 146    8.8
# 147    9.5
# 148    9.6
# 149    8.9
# Name: total, Length: 150, dtype: float64

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  total
# 0             5.1          3.5           1.4          0.2     setosa    8.6
# 1             4.9          3.0           1.4          0.2     setosa    7.9
# 2             4.7          3.2           1.3          0.2     setosa    7.9
# 3             4.6          3.1           1.5          0.2     setosa    7.7
# 4             5.0          3.6           1.4          0.2     setosa    8.6
# ..            ...          ...           ...          ...        ...    ...
# 145           6.7          3.0           5.2          2.3  virginica    9.7
# 146           6.3          2.5           5.0          1.9  virginica    8.8
# 147           6.5          3.0           5.2          2.0  virginica    9.5
# 148           6.2          3.4           5.4          2.3  virginica    9.6
# 149           5.9          3.0           5.1          1.8  virginica    8.9
#
# [150 rows x 6 columns]

# %%
#groupby mate
data.groupby('sepal_length')['sepal_width'].mean()
# Out:
# sepal_length
# 4.3    3.000000
# 4.4    3.033333
# 4.5    2.300000
# 4.6    3.325000
# 4.7    3.200000
# 4.8    3.180000
# 4.9    2.950000
# 5.0    3.120000
# 5.1    3.477778
# 5.2    3.425000
# 5.3    3.700000
# 5.4    3.550000
# 5.5    2.842857
# 5.6    2.816667
# 5.7    3.100000
# 5.8    2.885714
# 5.9    3.066667
# 6.0    2.733333
# 6.1    2.850000
# 6.2    2.825000
# 6.3    2.855556
# 6.4    2.957143
# 6.5    3.000000
# 6.6    2.950000
# 6.7    3.050000
# 6.8    3.000000
# 6.9    3.125000
# 7.0    3.200000
# 7.1    3.000000
# 7.2    3.266667
# 7.3    2.900000
# 7.4    2.800000
# 7.6    3.000000
# 7.7    3.050000
# 7.9    3.800000
# Name: sepal_width, dtype: float64

# %%
#vstack means vertically
d=np.vstack(data['sepal_width'])
d
# Out:
# array([[3.5],
#        [3. ],
#        [3.2],
#        [3.1],
#        [3.6],
#        [3.9],
#        [3.4],
#        [3.4],
#        [2.9],
#        [3.1],
#        [3.7],
#        [3.4],
#        [3. ],
#        [3. ],
#        [4. ],
#        [4.4],
#        [3.9],
#        [3.5],
#        [3.8],
#        [3.8],
#        [3.4],
#        [3.7],
#        [3.6],
#        [3.3],
#        [3.4],
#        [3. ],
#        [3.4],
#        [3.5],
#        [3.4],
#        [3.2],
#        [3.1],
#        [3.4],
#        [4.1],
#        [4.2],
#        [3.1],
#        [3.2],
#        [3.5],
#        [3.6],
#        [3. ],
#        [3.4],
#        [3.5],
#        [2.3],
#        [3.2],
#        [3.5],
#        [3.8],
#        [3. ],
#        [3.8],
#        [3.2],
#        [3.7],
#        [3.3],
#        [3.2],
#        [3.2],
#        [3.1],
#        [2.3],
#        [2.8],
#        [2.8],
#        [3.3],
#        [2.4],
#        [2.9],
#        [2.7],
#        [2. ],
#        [3. ],
# ...

# %%
#hstack means horizatanlly.
a=np.hstack(data['sepal_width'])
a
# Out:
# array([3.5, 3. , 3.2, 3.1, 3.6, 3.9, 3.4, 3.4, 2.9, 3.1, 3.7, 3.4, 3. ,
#        3. , 4. , 4.4, 3.9, 3.5, 3.8, 3.8, 3.4, 3.7, 3.6, 3.3, 3.4, 3. ,
#        3.4, 3.5, 3.4, 3.2, 3.1, 3.4, 4.1, 4.2, 3.1, 3.2, 3.5, 3.6, 3. ,
#        3.4, 3.5, 2.3, 3.2, 3.5, 3.8, 3. , 3.8, 3.2, 3.7, 3.3, 3.2, 3.2,
#        3.1, 2.3, 2.8, 2.8, 3.3, 2.4, 2.9, 2.7, 2. , 3. , 2.2, 2.9, 2.9,
#        3.1, 3. , 2.7, 2.2, 2.5, 3.2, 2.8, 2.5, 2.8, 2.9, 3. , 2.8, 3. ,
#        2.9, 2.6, 2.4, 2.4, 2.7, 2.7, 3. , 3.4, 3.1, 2.3, 3. , 2.5, 2.6,
#        3. , 2.6, 2.3, 2.7, 3. , 2.9, 2.9, 2.5, 2.8, 3.3, 2.7, 3. , 2.9,
#        3. , 3. , 2.5, 2.9, 2.5, 3.6, 3.2, 2.7, 3. , 2.5, 2.8, 3.2, 3. ,
#        3.8, 2.6, 2.2, 3.2, 2.8, 2.8, 2.7, 3.3, 3.2, 2.8, 3. , 2.8, 3. ,
#        2.8, 3.8, 2.8, 2.8, 2.6, 3. , 3.4, 3.1, 3. , 3.1, 3.1, 3.1, 2.7,
#        3.2, 3.3, 3. , 2.5, 3. , 3.4, 3. ])

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  total
# 0             5.1          3.5           1.4          0.2     setosa    8.6
# 1             4.9          3.0           1.4          0.2     setosa    7.9
# 2             4.7          3.2           1.3          0.2     setosa    7.9
# 3             4.6          3.1           1.5          0.2     setosa    7.7
# 4             5.0          3.6           1.4          0.2     setosa    8.6
# ..            ...          ...           ...          ...        ...    ...
# 145           6.7          3.0           5.2          2.3  virginica    9.7
# 146           6.3          2.5           5.0          1.9  virginica    8.8
# 147           6.5          3.0           5.2          2.0  virginica    9.5
# 148           6.2          3.4           5.4          2.3  virginica    9.6
# 149           5.9          3.0           5.1          1.8  virginica    8.9
#
# [150 rows x 6 columns]

# %%
#x for independent
#y for dependent
x=data[['sepal_length','sepal_width','petal_width','petal_length']]
y=data[['species']]
x,y
# Out:
# (     sepal_length  sepal_width  petal_width  petal_length
#  0             5.1          3.5          0.2           1.4
#  1             4.9          3.0          0.2           1.4
#  2             4.7          3.2          0.2           1.3
#  3             4.6          3.1          0.2           1.5
#  4             5.0          3.6          0.2           1.4
#  ..            ...          ...          ...           ...
#  145           6.7          3.0          2.3           5.2
#  146           6.3          2.5          1.9           5.0
#  147           6.5          3.0          2.0           5.2
#  148           6.2          3.4          2.3           5.4
#  149           5.9          3.0          1.8           5.1
#
#  [150 rows x 4 columns],
#         species
#  0       setosa
#  1       setosa
#  2       setosa
#  3       setosa
#  4       setosa
#  ..         ...
#  145  virginica
#  146  virginica
#  147  virginica
#  148  virginica
#  149  virginica
#
# ...

# %%
#perticular drop field
data.drop(columns=['total'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# split the data into two part
from sklearn import linear_model
#from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LinearRegression
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
x_train, x_test, y_train, y_test
# Out:
# (     sepal_length  sepal_width  petal_width  petal_length
#  65            6.7          3.1          1.4           4.4
#  39            5.1          3.4          0.2           1.5
#  89            5.5          2.5          1.3           4.0
#  8             4.4          2.9          0.2           1.4
#  1             4.9          3.0          0.2           1.4
#  ..            ...          ...          ...           ...
#  64            5.6          2.9          1.3           3.6
#  138           6.0          3.0          1.8           4.8
#  119           6.0          2.2          1.5           5.0
#  82            5.8          2.7          1.2           3.9
#  42            4.4          3.2          0.2           1.3
#
#  [120 rows x 4 columns],
#       sepal_length  sepal_width  petal_width  petal_length
#  91            6.1          3.0          1.4           4.6
#  47            4.6          3.2          0.2           1.4
# ...

# %%
plt.scatter(data['sepal_width'],data['sepal_length'],color='black')
plt.show()

# %%
sns.scatterplot(x=data['sepal_length'], y=data['sepal_width'], hue=data['species'], palette='viridis')# multiple color
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
# x=data['sepal_length']
# y=data['sepal_width']
# plt.scatter(data['sepal_length'],data['petal_length'],x,color='b')
plt.scatter(data['sepal_length'], data['petal_length'], color='r')  # 'r' stands for red

# %%
plt.scatter(data['sepal_length'], data['petal_width'], color='r', label='Petal Length')  # Red
plt.scatter(data['sepal_length'], data['sepal_length'], color='b', label='Sepal Width')   # Blue

plt.xlabel('Sepal Length')
plt.ylabel('Value')
plt.legend()  # Adds a legend to differentiate the points
plt.show()

# %%
#pie chart
b=['total','speeding','tata']
a=[1,2,3]
plt.pie(a,labels=b,shadow='true')
plt.legend()

# %%
from sklearn import linear_model
regression=linear_model.LinearRegression()
regression.fit(data[['sepal_length']],data.sepal_length)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression

regression = LinearRegression()
regression.fit(data[['sepal_length']], data['sepal_length'])  # Example target
# Out:
# LinearRegression()
